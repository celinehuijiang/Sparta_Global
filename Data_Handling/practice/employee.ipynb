# %%
import pandas as pd

# %%
df = pd.read_excel("Employee Sample Data.xlsx")
df
# Out:
#      Employee ID         Full Name                   Job Title   Department  \
# 0         E02002            Kai Le           Controls Engineer  Engineering
# 1         E02003      Robert Patel                     Analyst        Sales
# 2         E02004        Cameron Lo       Network Administrator           IT
# 3         E02005   Harper Castillo        IT Systems Architect           IT
# 4         E02006  Harper Dominguez                    Director  Engineering
# ...          ...               ...                         ...          ...
# 996       E02997    Melody Delgado           Network Architect           IT
# 997       E02998         Eliza Bui                     Analyst      Finance
# 998       E02999          Layla Wu  Sr. Account Representative        Sales
# 999       E03000        Thomas Lam           Controls Engineer  Engineering
# 1000      E03001     Willow Taylor      Account Representative        Sales
#
# ...

# %%
# dropiing the column 
columns_to_drop = ['Exit Date']  
df_1 = df.drop(columns=columns_to_drop)

# %%
df_1
# Out:
#      Employee ID         Full Name                   Job Title   Department  \
# 0         E02002            Kai Le           Controls Engineer  Engineering
# 1         E02003      Robert Patel                     Analyst        Sales
# 2         E02004        Cameron Lo       Network Administrator           IT
# 3         E02005   Harper Castillo        IT Systems Architect           IT
# 4         E02006  Harper Dominguez                    Director  Engineering
# ...          ...               ...                         ...          ...
# 996       E02997    Melody Delgado           Network Architect           IT
# 997       E02998         Eliza Bui                     Analyst      Finance
# 998       E02999          Layla Wu  Sr. Account Representative        Sales
# 999       E03000        Thomas Lam           Controls Engineer  Engineering
# 1000      E03001     Willow Taylor      Account Representative        Sales
#
# ...

# %%
# checking for any of the duplicate 
num_duplicates = df_1.duplicated().sum()
num_duplicates
# Out:
# 1

# %%
#removing the duplicate 
no_duplicate = df_1.drop_duplicates()
no_duplicate

#checking if there is anymore duplicate 
no_duplicate.duplicated().sum()
# Out:
# 0

# %%
# checking the date is correcly ordered 
is_ordered = no_duplicate['Hire Date'].is_monotonic

if is_ordered:
    print("Dates are correctly ordered.")
else:
    print("Dates are not correctly ordered.")
# Out:
# Dates are not correctly ordered.

# %%
# sort the DataFrame by the "Date" column from oldesr to newest
ordered_df = no_duplicate.sort_values('Hire Date')

# reset the index
ordered_df = ordered_df.reset_index(drop=True)

# print the updated DataFrame
ordered_df
# Out:
#     Employee ID        Full Name         Job Title       Department  \
# 0        E02752      Samuel Cruz       Sr. Manager  Human Resources
# 1        E02406   Gianna Alvarez  Business Partner  Human Resources
# 2        E02417           Ivy Do        Analyst II       Accounting
# 3        E02352          Ivy Liu        Analyst II        Marketing
# 4        E02902    Eloise Campos  Network Engineer               IT
# ..          ...              ...               ...              ...
# 995      E02224      Axel Bailey       Sr. Analyst        Marketing
# 996      E02109    Lillian Desai    Field Engineer      Engineering
# 997      E02267  Matthew Simmons       Sr. Manager       Accounting
# 998      E02928      Connor Ruiz           Manager       Accounting
# 999      E02758       Sadie Pham        Analyst II          Finance
#
#               Business Unit  Gender Ethnicity  Age  Hire Date  Annual Salary  \
# ...

# %%
# how to check for any white space 
whitespace_check = ordered_df['Job Title'].str.isspace()
whitespace_check.duplicated().sum()
# Out:
# 999

# %%
ordered_df = ordered_df
filename = 'clean.csv'
ordered_df.to_csv(filename, index=False)
